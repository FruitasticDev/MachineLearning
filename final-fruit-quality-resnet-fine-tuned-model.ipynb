# %%
from google.colab import drive

drive.mount('/content/drive')

# %%
# !pip install gdown
# Out:
# Collecting gdown
#   Downloading gdown-5.2.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.10/site-packages (from gdown) (4.12.3)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from gdown) (3.15.1)
# Requirement already satisfied: requests[socks] in /opt/conda/lib/python3.10/site-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from gdown) (4.66.4)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4->gdown) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (2024.6.2)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (1.7.1)
# Downloading gdown-5.2.0-py3-none-any.whl (18 kB)
# Installing collected packages: gdown
# Successfully installed gdown-5.2.0

# %%
import gdown

# a file
url = " https://drive.google.com/file/d/1-09sgSnfWQk6C4-m5nxVD7dRrT2IjnZQ/view?usp=sharing"
output = "FruQ_MK2.zip"
gdown.download(url, output, fuzzy=True)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1-09sgSnfWQk6C4-m5nxVD7dRrT2IjnZQ
# From (redirected): https://drive.google.com/uc?id=1-09sgSnfWQk6C4-m5nxVD7dRrT2IjnZQ&confirm=t&uuid=08fb90e2-fc19-474c-94d6-2c75da9d8913
# To: /kaggle/working/FruQ_MK2.zip
# 100%|██████████| 4.58G/4.58G [00:33<00:00, 137MB/s]
# 'FruQ_MK2.zip'

# %%
# !unzip /kaggle/working/FruQ_MK2.zip
# Out:
# Archive:  /kaggle/working/FruQ_MK2.zip
#    creating: content/FruQ-multi-new/content/FruQ-multi/
#    creating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/
#    creating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image287.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image29.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image187.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image377.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image191.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image89.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image437.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image443.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image37.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image219.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image249.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image315.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image115.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image211.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image79.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image11.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image375.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image155.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image161.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image373.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image81.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image59.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image195.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image201.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image335.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image131.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image225.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image447.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image151.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image7.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image329.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image149.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image97.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image403.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image139.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image285.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image179.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image141.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image427.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image359.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image127.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image57.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image343.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image19.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image331.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image197.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image177.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image153.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image263.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image415.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image407.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image261.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image221.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image429.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image73.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image275.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image327.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image67.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image361.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image363.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image269.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image171.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image291.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image25.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image379.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image21.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image297.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image99.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image145.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image271.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image313.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image109.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image395.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image305.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image409.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image295.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image223.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image401.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image369.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image417.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image371.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image381.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image247.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image441.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image157.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image445.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image339.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image203.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image397.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image303.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image367.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image63.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image365.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image45.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image105.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image405.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image235.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image121.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image289.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image87.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image101.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image71.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image387.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image349.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image273.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image117.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image321.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image351.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image17.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image135.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image453.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image237.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image69.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image125.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image133.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image173.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image83.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image229.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image301.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image245.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image5.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image165.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image49.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image385.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image391.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image435.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image129.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image47.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image53.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image421.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image251.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image347.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image253.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image355.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image267.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image411.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image323.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image65.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image341.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image169.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image189.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image419.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image1.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image209.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image357.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image199.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image123.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image311.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image399.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image27.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image293.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image393.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image231.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image433.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image39.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image309.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image91.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image15.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image423.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image205.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image319.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image389.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image277.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image137.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image413.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image175.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image193.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image183.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image259.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image451.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image213.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image185.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image257.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image299.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image181.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image143.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image163.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image103.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image23.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image227.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image325.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image147.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image283.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image85.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image41.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image113.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image233.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image265.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image31.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image239.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image35.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image307.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image255.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image425.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image95.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image383.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image13.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image241.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image167.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image119.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image281.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image75.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image107.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image9.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image217.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image33.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image345.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image243.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image439.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image43.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image279.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image353.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image93.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image77.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image159.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image61.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image431.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image449.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image51.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image317.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image55.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image111.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image207.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image215.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image333.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image337.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh/Image3.png
#    creating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image743.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image711.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image933.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image733.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image953.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image795.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image851.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image803.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image755.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image637.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image859.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image897.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image827.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image969.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image869.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image747.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image867.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image705.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image813.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image639.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image745.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image791.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image735.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image661.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image797.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image893.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image681.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image647.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image993.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image837.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image937.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image759.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image841.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image725.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image619.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image977.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image965.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image979.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image655.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image811.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image775.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image785.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image809.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image839.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image657.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image663.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image739.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image843.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image947.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image995.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image817.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image829.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image613.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image671.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image699.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image845.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image675.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image989.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image649.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image653.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image823.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image677.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image727.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image723.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image959.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image939.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image631.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image911.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image949.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image907.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image693.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image701.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image815.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image697.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image929.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image687.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image849.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image643.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image685.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image975.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image673.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image951.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image821.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image909.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image831.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image863.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image923.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image753.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image617.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image981.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image945.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image955.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image961.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image773.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image943.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image801.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image765.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image623.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image621.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image967.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image751.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image819.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image925.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image963.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image669.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image667.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image895.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image883.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image927.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image885.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image881.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image875.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image787.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image905.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image891.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image665.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image691.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image737.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image855.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image635.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image899.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image971.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image679.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image941.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image749.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image709.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image919.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image857.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image777.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image793.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image789.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image825.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image887.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image713.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image987.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image901.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image767.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image719.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image629.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image957.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image913.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image695.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image771.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image807.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image873.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image627.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image865.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image847.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image903.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image991.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image641.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image985.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image645.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image835.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image625.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image721.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image615.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image741.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image659.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image997.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image861.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image769.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image879.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image931.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image717.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image715.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image877.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image651.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image731.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image871.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image633.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image757.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image921.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image799.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image973.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image805.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image833.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image983.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image783.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image779.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image915.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image763.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image853.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image935.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image707.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image729.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image683.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image781.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image917.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image999.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image889.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image703.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image689.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild/Image761.png
#    creating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1321.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1087.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1849.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1123.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1161.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1775.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1227.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1157.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1121.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1847.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1741.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1695.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1187.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1319.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1713.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1765.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1355.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1179.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1257.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1271.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1061.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1801.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1787.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1317.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1127.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1703.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1085.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1761.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1385.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1201.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1719.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1363.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1191.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1717.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1041.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1151.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1213.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1221.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1239.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1189.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1357.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1091.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1053.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1365.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1195.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1059.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1853.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1287.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1323.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1125.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1001.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1353.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1805.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1295.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1275.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1219.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1685.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1267.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1303.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1343.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1031.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1263.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1159.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1005.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1105.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1359.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1769.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1043.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1711.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1133.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1767.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1291.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1103.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1277.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1211.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1681.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1735.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1259.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1379.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1313.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1269.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1691.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1737.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1739.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1193.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1815.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1789.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1361.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1163.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1131.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1723.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1165.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1841.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1217.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1065.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1785.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1111.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1143.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1167.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1371.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1733.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1699.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1721.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1153.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1055.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1705.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1751.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1229.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1743.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1773.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1249.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1137.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1183.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1093.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1341.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1729.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1207.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1795.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1827.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten/Image1033.png
# ...
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image997.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image1325.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image1281.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image861.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image769.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image879.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image1941.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image931.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image1971.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image1803.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image877.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image1821.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image1329.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image1793.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image1205.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image1243.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image871.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image1237.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image1833.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image1745.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image1251.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image1851.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image1177.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image921.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image799.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image973.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image1985.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image1727.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image805.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image833.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image1233.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image1345.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image1327.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image983.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image1763.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image1843.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image1181.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image1199.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image783.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image1879.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image779.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image1871.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image1315.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image915.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image1759.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image1337.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image1331.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image1857.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image1255.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image1861.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image853.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image1919.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image1203.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image1333.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image1791.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image935.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image1865.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image1175.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image1241.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image1223.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image1283.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image1273.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image1819.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image781.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image917.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image999.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image889.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild/Image1929.png
#    creating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image29.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image187.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image191.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image89.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image37.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image219.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image115.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image211.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image79.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image11.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image155.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image161.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image81.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image59.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image195.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image201.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image131.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image225.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image151.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image7.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image149.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image97.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image139.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image179.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image141.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image127.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image57.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image19.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image197.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image177.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image153.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image221.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image73.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image67.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image171.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image25.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image21.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image99.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image145.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image109.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image223.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image157.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image203.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image63.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image45.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image105.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image121.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image87.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image101.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image71.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image117.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image17.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image135.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image69.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image125.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image133.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image173.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image83.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image229.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image5.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image165.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image49.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image129.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image47.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image53.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image65.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image169.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image189.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image1.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image209.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image199.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image123.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image27.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image231.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image39.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image91.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image15.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image205.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image137.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image175.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image193.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image183.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image213.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image185.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image181.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image143.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image163.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image103.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image23.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image227.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image147.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image85.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image41.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image113.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image31.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image35.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image95.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image13.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image167.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image119.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image75.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image107.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image9.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image217.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image33.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image43.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image93.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image77.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image159.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image61.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image51.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image55.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image111.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image207.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image215.png
#   inflating: content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten/Image3.png

# %%
import os

import numpy as np

import matplotlib.pyplot as plt

import tensorflow as tf

from PIL import Image

import seaborn as sns

from collections import Counter, defaultdict

import shutil

from sklearn.metrics import confusion_matrix, classification_report

# %%
import shutil



shutil.rmtree("/kaggle/working/content/FruQ-multi-new/content/FruQ-multi/PepperQ")

shutil.rmtree('/kaggle/working/content/FruQ-multi-new/content/FruQ-multi/WatermeloQ')

# %%
path = r'/kaggle/working/content/FruQ-multi-new/content/FruQ-multi'

# %%
original_dir = path



# Define the root directory for the new folder structure

new_dir = r'FruQ-new'

# %%
import random



def restructure_dataset(original_dir, new_dir, max_images_per_class=300):

    """

    Restructure dataset from nested folders to flat fruit_quality folders

    with a limit on the number of images per class.



    Args:

        original_dir: Source directory with nested fruit folders

        new_dir: Destination directory for restructured dataset

        max_images_per_class: Maximum number of images to keep per class

    """

    # Create the new root directory if it doesn't exist

    os.makedirs(new_dir, exist_ok=True)



    # Iterate through the original directory and reorganize the folders

    for fruit in os.listdir(original_dir):

        fruit_path = os.path.join(original_dir, fruit)



        if not os.path.isdir(fruit_path):

            continue



        # Iterate through the "Fresh", "Mild", "Rotten" subdirectories

        for quality in os.listdir(fruit_path):

            quality_path = os.path.join(fruit_path, quality)



            if not os.path.isdir(quality_path):

                continue



            # Define the new folder name (e.g., "Banana_Fresh")

            new_folder_name = f"{fruit}_{quality}"

            new_folder_path = os.path.join(new_dir, new_folder_name)



            # Create the new folder if it doesn't exist

            os.makedirs(new_folder_path, exist_ok=True)



            # Get all image files

            image_files = [f for f in os.listdir(quality_path)

                           if f.lower().endswith(('.png', '.jpg', '.jpeg', '.gif'))]



            # Randomly select up to max_images_per_class

            selected_images = random.sample(image_files, min(len(image_files), max_images_per_class))



            # Copy selected images (instead of moving)

            for image_file in selected_images:

                old_image_path = os.path.join(quality_path, image_file)

                new_image_path = os.path.join(new_folder_path, image_file)



                # Use copy2 to preserve metadata

                shutil.copy2(old_image_path, new_image_path)



            print(f"Copied {len(selected_images)} images from {quality_path} to {new_folder_path}")



    print("Folder restructuring complete!")

# %%
restructure_dataset(path, new_dir)
# Out:
# Copied 136 images from /kaggle/working/content/FruQ-multi-new/content/FruQ-multi/PeachQ/Mild to FruQ-new/PeachQ_Mild
# Copied 300 images from /kaggle/working/content/FruQ-multi-new/content/FruQ-multi/PeachQ/Rotten to FruQ-new/PeachQ_Rotten
# Copied 300 images from /kaggle/working/content/FruQ-multi-new/content/FruQ-multi/PeachQ/Fresh to FruQ-new/PeachQ_Fresh
# Copied 226 images from /kaggle/working/content/FruQ-multi-new/content/FruQ-multi/KakiQ/Mild to FruQ-new/KakiQ_Mild
# Copied 300 images from /kaggle/working/content/FruQ-multi-new/content/FruQ-multi/KakiQ/Rotten to FruQ-new/KakiQ_Rotten
# Copied 300 images from /kaggle/working/content/FruQ-multi-new/content/FruQ-multi/KakiQ/Fresh to FruQ-new/KakiQ_Fresh
# Copied 300 images from /kaggle/working/content/FruQ-multi-new/content/FruQ-multi/AvocadoQ/Mild to FruQ-new/AvocadoQ_Mild
# Copied 100 images from /kaggle/working/content/FruQ-multi-new/content/FruQ-multi/AvocadoQ/Rotten to FruQ-new/AvocadoQ_Rotten
# Copied 300 images from /kaggle/working/content/FruQ-multi-new/content/FruQ-multi/AvocadoQ/Fresh to FruQ-new/AvocadoQ_Fresh
# Copied 250 images from /kaggle/working/content/FruQ-multi-new/content/FruQ-multi/PapayaQ/Mild to FruQ-new/PapayaQ_Mild
# Copied 300 images from /kaggle/working/content/FruQ-multi-new/content/FruQ-multi/PapayaQ/Rotten to FruQ-new/PapayaQ_Rotten
# Copied 130 images from /kaggle/working/content/FruQ-multi-new/content/FruQ-multi/PapayaQ/Fresh to FruQ-new/PapayaQ_Fresh
# Copied 300 images from /kaggle/working/content/FruQ-multi-new/content/FruQ-multi/tomatoQ/Mild to FruQ-new/tomatoQ_Mild
# Copied 300 images from /kaggle/working/content/FruQ-multi-new/content/FruQ-multi/tomatoQ/Rotten to FruQ-new/tomatoQ_Rotten
# Copied 300 images from /kaggle/working/content/FruQ-multi-new/content/FruQ-multi/tomatoQ/Fresh to FruQ-new/tomatoQ_Fresh
# Copied 194 images from /kaggle/working/content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Mild to FruQ-new/GrapefruitQ_Mild
# Copied 288 images from /kaggle/working/content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Rotten to FruQ-new/GrapefruitQ_Rotten
# Copied 227 images from /kaggle/working/content/FruQ-multi-new/content/FruQ-multi/GrapefruitQ/Fresh to FruQ-new/GrapefruitQ_Fresh
# Copied 96 images from /kaggle/working/content/FruQ-multi-new/content/FruQ-multi/BananaDB/Mild to FruQ-new/BananaDB_Mild
# Copied 300 images from /kaggle/working/content/FruQ-multi-new/content/FruQ-multi/BananaDB/Rotten to FruQ-new/BananaDB_Rotten
# Copied 179 images from /kaggle/working/content/FruQ-multi-new/content/FruQ-multi/BananaDB/Fresh to FruQ-new/BananaDB_Fresh
# Copied 300 images from /kaggle/working/content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Mild to FruQ-new/CucumberQ_Mild
# Copied 116 images from /kaggle/working/content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Rotten to FruQ-new/CucumberQ_Rotten
# Copied 250 images from /kaggle/working/content/FruQ-multi-new/content/FruQ-multi/CucumberQ/Fresh to FruQ-new/CucumberQ_Fresh
# Folder restructuring complete!

# %% [markdown]
# # Create dataset

# %%
  from tensorflow.keras import layers

  from tensorflow.keras.applications.resnet50 import preprocess_input



  SEED = 123

  IMG_SIZE = 224

  def create_dataset(data_dir, img_size=(IMG_SIZE, IMG_SIZE), batch_size=8, buffer_size=1000):



    # Define data augmentation layer

    data_augmentation = tf.keras.Sequential([

        layers.RandomFlip("horizontal"),

        layers.RandomRotation(0.2),

        layers.RandomZoom(0.2),

        layers.RandomBrightness(0.2),

        layers.RandomTranslation(0.2, 0.2)

    ])





    # Create the dataset

    train_data = tf.keras.utils.image_dataset_from_directory(

        data_dir,

        labels='inferred',

        label_mode='categorical',

        class_names=None,

        color_mode='rgb',

        batch_size=batch_size,

        image_size=img_size,

        shuffle=True,

        seed=SEED,

        validation_split=0.2,

        subset='training',

        interpolation='bilinear'

    )

    class_names = train_data.class_names



    # Combine data augmentation and preprocessing

    augmented_train_dataset = train_data.map(

        lambda x, y: (preprocess_input(data_augmentation(x, training=True)), y)

    )



    # Configure the dataset for performance

    train_data_optimized = augmented_train_dataset.cache()\
      .shuffle(buffer_size)\
      .prefetch(buffer_size=tf.data.AUTOTUNE)



    val_data = tf.keras.utils.image_dataset_from_directory(

        data_dir,

        labels='inferred',

        label_mode='categorical',

        class_names=class_names,

        color_mode='rgb',

        batch_size=batch_size,

        image_size=img_size,

        shuffle=True,

        seed=SEED,

        validation_split=0.2,

        subset='validation',

        interpolation='bilinear'

    )



    # Apply preprocessing to validation data as well

    val_data = val_data.map(lambda x, y: (preprocess_input(x), y))



    return train_data, train_data_optimized, val_data, class_names, augmented_train_dataset

# %%
# Create train and validation datasets

train_data, train_data_optimized, val_data, class_names, augmented_train_dataset = create_dataset(new_dir)

print(f"Images of train dataset have shape: {train_data.element_spec[0].shape}")

print(f"Labels of train dataset have shape: {train_data_optimized.element_spec[1].shape}")

print(f"Images of validation dataset have shape: {val_data.element_spec[0].shape}")

print(f"Labels of validation dataset have shape: {val_data.element_spec[1].shape}")

print(f"Class names are: {class_names}")
# Out:
# Found 5792 files belonging to 24 classes.
# Using 4634 files for training.
# Found 5792 files belonging to 24 classes.
# Using 1158 files for validation.
# Images of train dataset have shape: (None, 224, 224, 3)
# Labels of train dataset have shape: (None, 24)
# Images of validation dataset have shape: (None, 224, 224, 3)
# Labels of validation dataset have shape: (None, 24)
# Class names are: ['AvocadoQ_Fresh', 'AvocadoQ_Mild', 'AvocadoQ_Rotten', 'BananaDB_Fresh', 'BananaDB_Mild', 'BananaDB_Rotten', 'CucumberQ_Fresh', 'CucumberQ_Mild', 'CucumberQ_Rotten', 'GrapefruitQ_Fresh', 'GrapefruitQ_Mild', 'GrapefruitQ_Rotten', 'KakiQ_Fresh', 'KakiQ_Mild', 'KakiQ_Rotten', 'PapayaQ_Fresh', 'PapayaQ_Mild', 'PapayaQ_Rotten', 'PeachQ_Fresh', 'PeachQ_Mild', 'PeachQ_Rotten', 'tomatoQ_Fresh', 'tomatoQ_Mild', 'tomatoQ_Rotten']

# %%
from sklearn.utils.class_weight import compute_class_weight



y_train = np.concatenate([y.numpy() for _, y in train_data])

# Convert one-hot encoded labels back to class indices

y_train_classes = np.argmax(y_train, axis=1)



# Compute class weights

classes = np.unique(y_train_classes)

class_weights = compute_class_weight('balanced', classes=classes, y=y_train_classes)



# Convert to dictionary for TensorFlow

class_weight_dict = {i: weight for i, weight in enumerate(class_weights)}



print(class_weight_dict)
# Out:
# {0: 0.7913251366120219, 1: 0.7945816186556928, 2: 2.326305220883534, 3: 1.3408564814814814, 4: 2.4440928270042193, 5: 0.7512970168612192, 6: 0.9654166666666667, 7: 0.8112745098039216, 8: 2.298611111111111, 9: 1.0667587476979743, 10: 1.253787878787879, 11: 0.8939043209876543, 12: 0.7785618279569892, 13: 1.0667587476979743, 14: 0.8181497175141242, 15: 1.8929738562091503, 16: 0.9464869281045751, 17: 0.8468567251461988, 18: 0.7880952380952381, 19: 1.7714067278287462, 20: 0.7754350736278447, 21: 0.7880952380952381, 22: 0.8286838340486409, 23: 0.8358585858585859}

# %% [markdown]
# # 3. Model Creation

# %%
# def se_block(input_tensor, reduction_ratio=16):

#     """

#     Squeeze and Excitation block

#     """

#     channels = input_tensor.shape[-1]



#     # Squeeze operation (global average pooling)

#     x = layers.GlobalAveragePooling2D()(input_tensor)



#     # Excitation operation (two FC layers)

#     x = layers.Dense(channels // reduction_ratio, activation='relu')(x)

#     x = layers.BatchNormalization()(x)

#     x = layers.Dense(channels, activation='sigmoid')(x)



#     # Reshape to broadcasting shape

#     x = layers.Reshape((1, 1, channels))(x)



#     # Scale the input

#     return layers.multiply([input_tensor, x])

# %%
from tensorflow.keras.models import Model



def create_model(num_classes):

    base_model = tf.keras.applications.ResNet50(

        weights='imagenet',

        include_top=False,

        input_shape=(IMG_SIZE, IMG_SIZE, 3)

    )



    # Freeze base model

    base_model.trainable = False



    inputs = base_model.input

    x = base_model(inputs, training=False)

    x = tf.keras.layers.GlobalAveragePooling2D()(x)

    x = tf.keras.layers.Dropout(0.5)(x)

    x = tf.keras.layers.Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)

    outputs = tf.keras.layers.Dense(num_classes, activation='softmax')(x)





    # Create model

    model = Model(inputs=inputs, outputs=outputs, name='fruit_classifier')



    return model

# %% [markdown]
# # 4. Model Compilation

# %%
def compile_model(model):

    model.compile(

        optimizer = tf.keras.optimizers.Adam(

        learning_rate=0.001

    ),

        loss='categorical_crossentropy',

        metrics=['accuracy']

    )

# %% [markdown]
# # 5. Callbacks

# %%
import datetime



# Create log directory with timestamp

log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")

# %%
def create_callbacks():

    return [

        tf.keras.callbacks.EarlyStopping(

            monitor='val_loss',

            patience=10,

            restore_best_weights=True,

            min_delta=0.001

        ),

        tf.keras.callbacks.ModelCheckpoint(

            filepath=os.path.join(log_dir, 'model-{epoch:02d}-{val_accuracy:.2f}.keras'),

            monitor='val_accuracy',

            save_best_only=True,

            mode='max',

        ),

        tf.keras.callbacks.ReduceLROnPlateau(

            monitor='val_loss',

            factor=0.2,

            patience=5,

            min_lr=1e-6

        )

    ]

# %% [markdown]
# # 6. Training History Plotting

# %%
def plot_training_history(history, title):

    plt.figure(figsize=(12, 4))



    # Plot accuracy

    plt.subplot(1, 2, 1)

    plt.plot(history.history['accuracy'])

    plt.plot(history.history['val_accuracy'])

    plt.title(f'{title} - Accuracy')

    plt.ylabel('Accuracy')

    plt.xlabel('Epoch')

    plt.legend(['Train', 'Validation'])



    # Plot loss

    plt.subplot(1, 2, 2)

    plt.plot(history.history['loss'])

    plt.plot(history.history['val_loss'])

    plt.title(f'{title} - Loss')

    plt.ylabel('Loss')

    plt.xlabel('Epoch')

    plt.legend(['Train', 'Validation'])



    plt.tight_layout()

    plt.show()

# %% [markdown]
# # 7. Metric

# %%
def metric(model, dataset, class_names, title="Confusion Matrix"):

    # Get true labels and predictions

    y_true = []

    y_pred = []



    for images, labels in dataset:

        # Append true labels

        y_true.extend(np.argmax(labels.numpy(), axis=1))



        # Predict on images

        predictions = model.predict(images)

        y_pred.extend(np.argmax(predictions, axis=1))



    y_true = np.array(y_true)

    y_pred = np.array(y_pred)



    # Create confusion matrix

    cm = confusion_matrix(y_true, y_pred)



    # Plot confusion matrix

    plt.figure(figsize=(12, 8))

    plt.subplot(1, 2, 1)

    sns.heatmap(

        cm,

        annot=True,

        fmt='d',

        cmap='Blues',

        xticklabels=class_names,

        yticklabels=class_names

    )

    plt.title(f"{title}\nConfusion Matrix")

    plt.ylabel('True Label')

    plt.xlabel('Predicted Label')



    # Generate classification report

    report = classification_report(

        y_true,

        y_pred,

        target_names=class_names,

        output_dict=True

    )



    # Create metrics visualization

    plt.subplot(1, 2, 2)

    metrics_data = {

        'Precision': [],

        'Recall': [],

        'F1-Score': []

    }



    # Get metrics for each class

    for class_name in class_names:

        metrics_data['Precision'].append(report[class_name]['precision'])

        metrics_data['Recall'].append(report[class_name]['recall'])

        metrics_data['F1-Score'].append(report[class_name]['f1-score'])



    # Add macro average

    metrics_data['Precision'].append(report['macro avg']['precision'])

    metrics_data['Recall'].append(report['macro avg']['recall'])

    metrics_data['F1-Score'].append(report['macro avg']['f1-score'])



    # Create labels for all classes plus macro average

    all_labels = class_names + ['Macro Avg']

    x = np.arange(len(all_labels))

    width = 0.25



    # Plot bars for each metric

    plt.bar(x - width, metrics_data['Precision'], width, label='Precision')

    plt.bar(x, metrics_data['Recall'], width, label='Recall')

    plt.bar(x + width, metrics_data['F1-Score'], width, label='F1-Score')



    plt.xlabel('Classes')

    plt.ylabel('Score')

    plt.title(f'{title}\nPrecision, Recall, and F1-Score')

    plt.xticks(x, all_labels, rotation=45)

    plt.legend()

    plt.tight_layout()

    plt.show()



    # Print detailed classification report

    print("\nDetailed Classification Report:")

    print("\nPer-Class Metrics:")

    print("-" * 60)

    for class_name in class_names:

        print(f"\n{class_name}:")

        print(f"Precision: {report[class_name]['precision']:.3f}")

        print(f"Recall: {report[class_name]['recall']:.3f}")

        print(f"F1-Score: {report[class_name]['f1-score']:.3f}")



    print("\nMacro-Averaged Metrics:")

    print("-" * 60)

    print(f"Macro Precision: {report['macro avg']['precision']:.3f}")

    print(f"Macro Recall: {report['macro avg']['recall']:.3f}")

    print(f"Macro F1-Score: {report['macro avg']['f1-score']:.3f}")



    # Print support (number of samples per class)

    print("\nClass Support (Number of Samples):")

    print("-" * 60)

    for class_name in class_names:

        print(f"{class_name}: {report[class_name]['support']}")

# %%
def evaluate_models(model, val):

  classes = class_names

  metric(

      model,

      val,

      classes,

      f"{type} Classification Confusion Matrix"

  )

# %% [markdown]
# # 8. Model Training Function

# %%
fruit_model = create_model(

        num_classes=len(class_names)

    )



compile_model(fruit_model)

# %%
fruit_model.summary()
# Out:
# Model: "fruit_classifier"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)           │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ resnet50 (Functional)                │ (None, 7, 7, 2048)          │      23,587,712 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 2048)                │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │         262,272 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 24)                  │           3,096 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 23,853,080 (90.99 MB)
#  Trainable params: 265,368 (1.01 MB)
#  Non-trainable params: 23,587,712 (89.98 MB)

# %%
history = fruit_model.fit(train_data_optimized,

                    epochs=50,

                    validation_data=val_data,

                    callbacks=create_callbacks(),

                    class_weight=class_weight_dict

                    )
# Out:
# Epoch 1/50
# 580/580 ━━━━━━━━━━━━━━━━━━━━ 245s 118ms/step - accuracy: 0.7193 - loss: 2.5682 - val_accuracy: 0.8048 - val_loss: 1.0825 - learning_rate: 0.0010
# Epoch 2/50
# 580/580 ━━━━━━━━━━━━━━━━━━━━ 48s 82ms/step - accuracy: 0.8963 - loss: 0.7771 - val_accuracy: 0.9413 - val_loss: 0.6260 - learning_rate: 0.0010
# Epoch 3/50
# 580/580 ━━━━━━━━━━━━━━━━━━━━ 93s 101ms/step - accuracy: 0.9077 - loss: 0.6505 - val_accuracy: 0.9085 - val_loss: 0.4934 - learning_rate: 0.0010
# Epoch 4/50
# 580/580 ━━━━━━━━━━━━━━━━━━━━ 68s 77ms/step - accuracy: 0.9040 - loss: 0.5264 - val_accuracy: 0.9326 - val_loss: 0.4422 - learning_rate: 0.0010
# Epoch 5/50
# 580/580 ━━━━━━━━━━━━━━━━━━━━ 97s 102ms/step - accuracy: 0.9106 - loss: 0.5256 - val_accuracy: 0.9465 - val_loss: 0.4394 - learning_rate: 0.0010
# Epoch 6/50
# 580/580 ━━━━━━━━━━━━━━━━━━━━ 45s 78ms/step - accuracy: 0.9090 - loss: 0.5217 - val_accuracy: 0.9663 - val_loss: 0.3651 - learning_rate: 0.0010
# Epoch 7/50
# 580/580 ━━━━━━━━━━━━━━━━━━━━ 95s 101ms/step - accuracy: 0.9144 - loss: 0.5062 - val_accuracy: 0.8135 - val_loss: 0.6939 - learning_rate: 0.0010
# Epoch 8/50
# 580/580 ━━━━━━━━━━━━━━━━━━━━ 66s 73ms/step - accuracy: 0.9193 - loss: 0.4728 - val_accuracy: 0.9197 - val_loss: 0.4718 - learning_rate: 0.0010
# Epoch 9/50
# 580/580 ━━━━━━━━━━━━━━━━━━━━ 43s 74ms/step - accuracy: 0.9154 - loss: 0.5046 - val_accuracy: 0.8566 - val_loss: 0.5619 - learning_rate: 0.0010
# Epoch 10/50
# 580/580 ━━━━━━━━━━━━━━━━━━━━ 97s 101ms/step - accuracy: 0.9164 - loss: 0.5067 - val_accuracy: 0.9456 - val_loss: 0.3710 - learning_rate: 0.0010
# Epoch 11/50
# 580/580 ━━━━━━━━━━━━━━━━━━━━ 83s 103ms/step - accuracy: 0.9121 - loss: 0.4846 - val_accuracy: 0.9672 - val_loss: 0.3725 - learning_rate: 0.0010
# Epoch 12/50
# 580/580 ━━━━━━━━━━━━━━━━━━━━ 67s 77ms/step - accuracy: 0.9364 - loss: 0.3858 - val_accuracy: 0.9611 - val_loss: 0.2955 - learning_rate: 2.0000e-04
# Epoch 13/50
# 580/580 ━━━━━━━━━━━━━━━━━━━━ 96s 101ms/step - accuracy: 0.9454 - loss: 0.3100 - val_accuracy: 0.9637 - val_loss: 0.2661 - learning_rate: 2.0000e-04
# Epoch 14/50
# 580/580 ━━━━━━━━━━━━━━━━━━━━ 66s 74ms/step - accuracy: 0.9515 - loss: 0.2771 - val_accuracy: 0.9534 - val_loss: 0.2486 - learning_rate: 2.0000e-04
# Epoch 15/50
# 580/580 ━━━━━━━━━━━━━━━━━━━━ 83s 76ms/step - accuracy: 0.9516 - loss: 0.2525 - val_accuracy: 0.9698 - val_loss: 0.2271 - learning_rate: 2.0000e-04
# Epoch 16/50
# 580/580 ━━━━━━━━━━━━━━━━━━━━ 97s 101ms/step - accuracy: 0.9520 - loss: 0.2413 - val_accuracy: 0.9698 - val_loss: 0.2050 - learning_rate: 2.0000e-04
# Epoch 17/50
# 580/580 ━━━━━━━━━━━━━━━━━━━━ 67s 76ms/step - accuracy: 0.9534 - loss: 0.2372 - val_accuracy: 0.9534 - val_loss: 0.2298 - learning_rate: 2.0000e-04
# Epoch 18/50
# 580/580 ━━━━━━━━━━━━━━━━━━━━ 96s 101ms/step - accuracy: 0.9569 - loss: 0.2242 - val_accuracy: 0.9603 - val_loss: 0.2125 - learning_rate: 2.0000e-04
# Epoch 19/50
# 580/580 ━━━━━━━━━━━━━━━━━━━━ 69s 79ms/step - accuracy: 0.9569 - loss: 0.2180 - val_accuracy: 0.9758 - val_loss: 0.1891 - learning_rate: 2.0000e-04
# Epoch 20/50
# 580/580 ━━━━━━━━━━━━━━━━━━━━ 94s 101ms/step - accuracy: 0.9575 - loss: 0.2107 - val_accuracy: 0.9396 - val_loss: 0.2364 - learning_rate: 2.0000e-04
# Epoch 21/50
# 580/580 ━━━━━━━━━━━━━━━━━━━━ 67s 75ms/step - accuracy: 0.9562 - loss: 0.2182 - val_accuracy: 0.9775 - val_loss: 0.1869 - learning_rate: 2.0000e-04
# Epoch 22/50
# 580/580 ━━━━━━━━━━━━━━━━━━━━ 97s 101ms/step - accuracy: 0.9517 - loss: 0.2142 - val_accuracy: 0.9620 - val_loss: 0.1989 - learning_rate: 2.0000e-04
# Epoch 23/50
# 580/580 ━━━━━━━━━━━━━━━━━━━━ 66s 74ms/step - accuracy: 0.9641 - loss: 0.2020 - val_accuracy: 0.9534 - val_loss: 0.2018 - learning_rate: 2.0000e-04
# Epoch 24/50
# 580/580 ━━━━━━━━━━━━━━━━━━━━ 97s 101ms/step - accuracy: 0.9565 - loss: 0.2106 - val_accuracy: 0.9542 - val_loss: 0.2061 - learning_rate: 2.0000e-04
# Epoch 25/50
# 580/580 ━━━━━━━━━━━━━━━━━━━━ 68s 77ms/step - accuracy: 0.9548 - loss: 0.2086 - val_accuracy: 0.9732 - val_loss: 0.1828 - learning_rate: 2.0000e-04
# Epoch 26/50
# 580/580 ━━━━━━━━━━━━━━━━━━━━ 82s 77ms/step - accuracy: 0.9675 - loss: 0.1927 - val_accuracy: 0.9551 - val_loss: 0.1847 - learning_rate: 2.0000e-04
# Epoch 27/50
# 580/580 ━━━━━━━━━━━━━━━━━━━━ 82s 77ms/step - accuracy: 0.9582 - loss: 0.1974 - val_accuracy: 0.9724 - val_loss: 0.1749 - learning_rate: 2.0000e-04
# Epoch 28/50
# 580/580 ━━━━━━━━━━━━━━━━━━━━ 96s 101ms/step - accuracy: 0.9538 - loss: 0.2084 - val_accuracy: 0.9396 - val_loss: 0.2134 - learning_rate: 2.0000e-04
# Epoch 29/50
# 580/580 ━━━━━━━━━━━━━━━━━━━━ 82s 101ms/step - accuracy: 0.9612 - loss: 0.1987 - val_accuracy: 0.9732 - val_loss: 0.1762 - learning_rate: 2.0000e-04
# Epoch 30/50
# 580/580 ━━━━━━━━━━━━━━━━━━━━ 66s 74ms/step - accuracy: 0.9566 - loss: 0.2086 - val_accuracy: 0.9603 - val_loss: 0.1960 - learning_rate: 2.0000e-04
# Epoch 31/50
# 580/580 ━━━━━━━━━━━━━━━━━━━━ 43s 74ms/step - accuracy: 0.9621 - loss: 0.1968 - val_accuracy: 0.9775 - val_loss: 0.1706 - learning_rate: 2.0000e-04
# Epoch 32/50
# 580/580 ━━━━━━━━━━━━━━━━━━━━ 83s 76ms/step - accuracy: 0.9612 - loss: 0.1952 - val_accuracy: 0.9741 - val_loss: 0.1734 - learning_rate: 2.0000e-04
# Epoch 33/50
# 580/580 ━━━━━━━━━━━━━━━━━━━━ 82s 77ms/step - accuracy: 0.9640 - loss: 0.1861 - val_accuracy: 0.9663 - val_loss: 0.1798 - learning_rate: 2.0000e-04
# Epoch 34/50
# 580/580 ━━━━━━━━━━━━━━━━━━━━ 96s 101ms/step - accuracy: 0.9624 - loss: 0.1885 - val_accuracy: 0.9516 - val_loss: 0.1775 - learning_rate: 2.0000e-04
# Epoch 35/50
# 580/580 ━━━━━━━━━━━━━━━━━━━━ 45s 77ms/step - accuracy: 0.9633 - loss: 0.1922 - val_accuracy: 0.9516 - val_loss: 0.2067 - learning_rate: 2.0000e-04
# Epoch 36/50
# 580/580 ━━━━━━━━━━━━━━━━━━━━ 81s 76ms/step - accuracy: 0.9644 - loss: 0.1939 - val_accuracy: 0.9637 - val_loss: 0.1717 - learning_rate: 2.0000e-04
# Epoch 37/50
# 580/580 ━━━━━━━━━━━━━━━━━━━━ 97s 101ms/step - accuracy: 0.9644 - loss: 0.1843 - val_accuracy: 0.9758 - val_loss: 0.1557 - learning_rate: 4.0000e-05
# Epoch 38/50
# 580/580 ━━━━━━━━━━━━━━━━━━━━ 44s 75ms/step - accuracy: 0.9737 - loss: 0.1678 - val_accuracy: 0.9715 - val_loss: 0.1556 - learning_rate: 4.0000e-05
# Epoch 39/50
# 580/580 ━━━━━━━━━━━━━━━━━━━━ 59s 103ms/step - accuracy: 0.9667 - loss: 0.1666 - val_accuracy: 0.9784 - val_loss: 0.1481 - learning_rate: 4.0000e-05
# Epoch 40/50
# 580/580 ━━━━━━━━━━━━━━━━━━━━ 45s 78ms/step - accuracy: 0.9657 - loss: 0.1635 - val_accuracy: 0.9741 - val_loss: 0.1471 - learning_rate: 4.0000e-05
# Epoch 41/50
# 580/580 ━━━━━━━━━━━━━━━━━━━━ 95s 101ms/step - accuracy: 0.9685 - loss: 0.1652 - val_accuracy: 0.9741 - val_loss: 0.1474 - learning_rate: 4.0000e-05
# Epoch 42/50
# 580/580 ━━━━━━━━━━━━━━━━━━━━ 66s 73ms/step - accuracy: 0.9710 - loss: 0.1623 - val_accuracy: 0.9732 - val_loss: 0.1490 - learning_rate: 4.0000e-05
# Epoch 43/50
# 580/580 ━━━━━━━━━━━━━━━━━━━━ 98s 101ms/step - accuracy: 0.9688 - loss: 0.1609 - val_accuracy: 0.9724 - val_loss: 0.1561 - learning_rate: 4.0000e-05
# Epoch 44/50
# 580/580 ━━━━━━━━━━━━━━━━━━━━ 65s 73ms/step - accuracy: 0.9727 - loss: 0.1544 - val_accuracy: 0.9698 - val_loss: 0.1486 - learning_rate: 4.0000e-05
# Epoch 45/50
# 580/580 ━━━━━━━━━━━━━━━━━━━━ 99s 102ms/step - accuracy: 0.9732 - loss: 0.1547 - val_accuracy: 0.9758 - val_loss: 0.1406 - learning_rate: 4.0000e-05
# Epoch 46/50
# 580/580 ━━━━━━━━━━━━━━━━━━━━ 67s 77ms/step - accuracy: 0.9731 - loss: 0.1520 - val_accuracy: 0.9689 - val_loss: 0.1555 - learning_rate: 4.0000e-05
# Epoch 47/50
# 580/580 ━━━━━━━━━━━━━━━━━━━━ 96s 101ms/step - accuracy: 0.9766 - loss: 0.1499 - val_accuracy: 0.9680 - val_loss: 0.1472 - learning_rate: 4.0000e-05
# Epoch 48/50
# 580/580 ━━━━━━━━━━━━━━━━━━━━ 44s 76ms/step - accuracy: 0.9720 - loss: 0.1534 - val_accuracy: 0.9758 - val_loss: 0.1479 - learning_rate: 4.0000e-05
# Epoch 49/50
# 580/580 ━━━━━━━━━━━━━━━━━━━━ 96s 101ms/step - accuracy: 0.9785 - loss: 0.1440 - val_accuracy: 0.9680 - val_loss: 0.1529 - learning_rate: 4.0000e-05
# Epoch 50/50
# 580/580 ━━━━━━━━━━━━━━━━━━━━ 68s 77ms/step - accuracy: 0.9728 - loss: 0.1491 - val_accuracy: 0.9655 - val_loss: 0.1568 - learning_rate: 4.0000e-05

# %%
fruit_model.save('fruit_classifier_final.keras')

# %%
fruit_model.save('fruit_classifier_final.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
plot_training_history(history, "Fruit Classification")

# %%
evaluate_models(fruit_model, val_data)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# Detailed Classification Report:
#
# Per-Class Metrics:
# ------------------------------------------------------------
#
# AvocadoQ_Fresh:
# Precision: 1.000
# Recall: 1.000
# F1-Score: 1.000
#
# AvocadoQ_Mild:
# Precision: 1.000
# Recall: 1.000
# F1-Score: 1.000
#
# AvocadoQ_Rotten:
# Precision: 1.000
# Recall: 1.000
# F1-Score: 1.000
#
# BananaDB_Fresh:
# Precision: 1.000
# Recall: 0.943
# F1-Score: 0.971
#
# BananaDB_Mild:
# Precision: 0.810
# Recall: 1.000
# F1-Score: 0.895
#
# BananaDB_Rotten:
# Precision: 1.000
# Recall: 0.953
# F1-Score: 0.976
#
# CucumberQ_Fresh:
# Precision: 1.000
# Recall: 1.000
# F1-Score: 1.000
#
# CucumberQ_Mild:
# Precision: 1.000
# Recall: 1.000
# F1-Score: 1.000
#
# CucumberQ_Rotten:
# Precision: 1.000
# Recall: 1.000
# F1-Score: 1.000
#
# GrapefruitQ_Fresh:
# Precision: 1.000
# Recall: 1.000
# F1-Score: 1.000
#
# GrapefruitQ_Mild:
# Precision: 0.930
# Recall: 1.000
# F1-Score: 0.964
#
# GrapefruitQ_Rotten:
# Precision: 1.000
# Recall: 0.958
# F1-Score: 0.979
#
# KakiQ_Fresh:
# Precision: 1.000
# Recall: 1.000
# F1-Score: 1.000
#
# KakiQ_Mild:
# Precision: 1.000
# Recall: 0.978
# F1-Score: 0.989
#
# KakiQ_Rotten:
# Precision: 0.985
# Recall: 1.000
# F1-Score: 0.992
#
# PapayaQ_Fresh:
# Precision: 0.718
# Recall: 1.000
# F1-Score: 0.836
#
# PapayaQ_Mild:
# Precision: 1.000
# Recall: 0.761
# F1-Score: 0.864
#
# PapayaQ_Rotten:
# Precision: 1.000
# Recall: 1.000
# F1-Score: 1.000
#
# PeachQ_Fresh:
# Precision: 1.000
# Recall: 1.000
# F1-Score: 1.000
#
# PeachQ_Mild:
# Precision: 1.000
# Recall: 1.000
# F1-Score: 1.000
#
# PeachQ_Rotten:
# Precision: 1.000
# Recall: 1.000
# F1-Score: 1.000
#
# tomatoQ_Fresh:
# Precision: 1.000
# Recall: 0.855
# F1-Score: 0.922
#
# tomatoQ_Mild:
# Precision: 0.892
# Recall: 0.985
# F1-Score: 0.936
#
# tomatoQ_Rotten:
# Precision: 0.986
# Recall: 1.000
# F1-Score: 0.993
#
# Macro-Averaged Metrics:
# ------------------------------------------------------------
# Macro Precision: 0.972
# Macro Recall: 0.976
# Macro F1-Score: 0.971
#
# Class Support (Number of Samples):
# ------------------------------------------------------------
# AvocadoQ_Fresh: 56.0
# AvocadoQ_Mild: 57.0
# AvocadoQ_Rotten: 17.0
# BananaDB_Fresh: 35.0
# BananaDB_Mild: 17.0
# BananaDB_Rotten: 43.0
# CucumberQ_Fresh: 50.0
# CucumberQ_Mild: 62.0
# CucumberQ_Rotten: 32.0
# GrapefruitQ_Fresh: 46.0
# GrapefruitQ_Mild: 40.0
# GrapefruitQ_Rotten: 72.0
# KakiQ_Fresh: 52.0
# KakiQ_Mild: 45.0
# KakiQ_Rotten: 64.0
# PapayaQ_Fresh: 28.0
# PapayaQ_Mild: 46.0
# PapayaQ_Rotten: 72.0
# PeachQ_Fresh: 55.0
# PeachQ_Mild: 27.0
# PeachQ_Rotten: 51.0
# tomatoQ_Fresh: 55.0
# tomatoQ_Mild: 67.0
# tomatoQ_Rotten: 69.0

# %%
# clear session for next train if want to

tf.keras.backend.clear_session(

    free_memory=True

)

# %%
def load_and_preprocess_image(image_path, img_size=(224, 224)):

    """

    Load and preprocess an image for model prediction.

    """

    img = tf.keras.preprocessing.image.load_img(

        image_path,

        target_size=img_size

    )

    img_array = tf.keras.preprocessing.image.img_to_array(img)

    img_array = tf.expand_dims(img_array, 0)  # Add batch dimension

    img_array = tf.keras.applications.resnet50.preprocess_input(img_array)  # Use ResNet preprocessing

    return img_array



def predict_image(image_path, model, classes):

    """

    Predict the fruit type and its quality based on the given image.



    Args:

        image_path (str): Path to the input image.

        model (tf.keras.Model): Trained model for fruit classification.

        classes (list): List of fruit class names.

    Returns:

        dict: Prediction results including fruit type, quality, and confidence scores.

    """

    # Preprocess image

    img = load_and_preprocess_image(image_path)



    # Predict using the models

    pred = model.predict(img)



    # Get class predictions and confidence scores

    index = np.argmax(pred)



    return {

        'fruit': classes[index],

        'confidence': float(np.max(pred)),

    }

# %%
prediction = predict_image(

    image_path='/content/drive/MyDrive/Kepston_bangkit/banana_agak_busuk.jpg',

    model=fruit_model,

    classes=class_names

)



print(prediction)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# {'fruit': 'BananaDB_Rotten', 'confidence': 0.8021975755691528}

# %%
def fine_tune_model(model, base_model, fine_tune_at, learning_rate=1e-5):
    """
    Fine-tune the given model starting from `fine_tune_at` layer.

    Args:
        model (tf.keras.Model): The previously trained model.
        base_model (tf.keras.Model): The base model (e.g., ResNet50).
        fine_tune_at (int): Layer index from which to start unfreezing.
        learning_rate (float): Lower learning rate for fine-tuning.
    
    Returns:
        tf.keras.Model: Fine-tuned model.
    """
    len(base_model.layers)
    
    # Unfreeze the base model starting from `fine_tune_at`
    base_model.trainable = True
    for layer in base_model.layers[:fine_tune_at]:
        layer.trainable = False

    # Recompile the model with a lower learning rate
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

    return model

# %%
# Define the base model
base_model = tf.keras.applications.ResNet50(
    weights='imagenet',
    include_top=False,
    input_shape=(IMG_SIZE, IMG_SIZE, 3)
)

# Load the pre-trained model (if saved earlier)
model_path = '/kaggle/input/fruit_classifier_final/tensorflow2/default/1/fruit_classifier_final.keras'
model = tf.keras.models.load_model(model_path)

# model.load_weights('path_to_saved_weights.h5')  # Optional

# Fine-tune the model
fine_tune_at_layer = 140  # Adjust as needed based on model's layer structure
fine_tuned_model = fine_tune_model(model, base_model, fine_tune_at=fine_tune_at_layer)

# %%
# layers are in the base model
print("Number of layers in the base model: ", len(base_model.layers))
# Out:
# Number of layers in the base model:  175

# %%
fine_tuned_model.summary()
# Out:
# Model: "fruit_classifier"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ resnet50 (Functional)           │ (None, 7, 7, 2048)     │    23,587,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 24)             │         3,096 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 23,853,080 (90.99 MB)
#  Trainable params: 265,368 (1.01 MB)
#  Non-trainable params: 23,587,712 (89.98 MB)

# %%
def finetune_callbacks():

    return [

        tf.keras.callbacks.EarlyStopping(

            monitor='val_loss',

            patience=3,

            restore_best_weights=True,

            min_delta=0.001

        ),

        tf.keras.callbacks.ModelCheckpoint(

            filepath=os.path.join(log_dir, 'model-{epoch:02d}-{val_accuracy:.2f}.keras'),

            monitor='val_accuracy',

            save_best_only=True,

            mode='max',

        ),

        tf.keras.callbacks.ReduceLROnPlateau(

            monitor='val_loss',

            factor=0.2,

            patience=4,

            min_lr=1e-6

        )

    ]

# %%
fine_tune_history = fine_tuned_model.fit(
    train_data,
    validation_data=val_data,
    epochs=15,  # fewer epochs for fine-tuning
    callbacks=finetune_callbacks(),
     class_weight=class_weight_dict
)
# Out:
# Epoch 1/15
# 580/580 ━━━━━━━━━━━━━━━━━━━━ 39s 67ms/step - accuracy: 0.9613 - loss: 0.1774 - val_accuracy: 0.9491 - val_loss: 0.1932 - learning_rate: 1.0000e-05
# Epoch 2/15
# 580/580 ━━━━━━━━━━━━━━━━━━━━ 39s 67ms/step - accuracy: 0.9582 - loss: 0.1745 - val_accuracy: 0.9525 - val_loss: 0.1899 - learning_rate: 1.0000e-05
# Epoch 3/15
# 580/580 ━━━━━━━━━━━━━━━━━━━━ 38s 65ms/step - accuracy: 0.9701 - loss: 0.1640 - val_accuracy: 0.9439 - val_loss: 0.1904 - learning_rate: 1.0000e-05
# Epoch 4/15
# 580/580 ━━━━━━━━━━━━━━━━━━━━ 37s 65ms/step - accuracy: 0.9635 - loss: 0.1687 - val_accuracy: 0.9421 - val_loss: 0.1913 - learning_rate: 1.0000e-05
# Epoch 5/15
# 580/580 ━━━━━━━━━━━━━━━━━━━━ 38s 66ms/step - accuracy: 0.9722 - loss: 0.1531 - val_accuracy: 0.9387 - val_loss: 0.1986 - learning_rate: 1.0000e-05

# %%
plot_training_history(fine_tune_history, "Fruit Classification")

# %%
fine_tuned_model.save('fruit_classifier_final_improved_fine_tuned.keras')
